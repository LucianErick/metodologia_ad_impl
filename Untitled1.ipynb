# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sb

# %%
# %matplotlib inline

# %%
data = pd.read_excel('./sheetset.xls')
data.head(50)
# Out:
#     idade conhece_ux  nivel_conhecimento  experiencia_design  importancia_ux  \
# 0      23        Sim                   0                   1               4
# 1      23        Sim                   1                   4               5
# 2      27        Sim                   1                   2               5
# 3      31        Sim                   1                   1               4
# 4      19        Sim                   1                   3               5
# 5      20        Sim                   2                   4               5
# 6      20        Sim                   1                   4               5
# 7      21        Sim                   2                   3               5
# 8      20        Sim                   2                   1               4
# 9      21        Sim                   1                   4               5
# 10     19        Sim                   1                   3               5
# 11     18        Sim                   1                   5               5
# 12     24        Sim                   1                   4               5
# 13     23        Sim                   2                   3               5
# 14     20        Sim                   2                   3               5
# 15     21        Sim                   1                   3               5
# 16     19        Não                   2                   1               5
# 17     21        Sim                   0                   3               5
# 18     22        Não                   1                   1               5
# 19     39        Não                   2                   1               5
# 20     22        Não                   2                   1               4
# 21     20        Sim                   2                   1               5
# 22     21        Não                   2                   1               4
# 23     25        Sim                   1                   4               5
# 24     20        Sim                   2                   1               5
# 25     22        Sim                   1                   3               5
# 26     29        Sim                   2                   2               5
# 27     22        Sim                   0                   1               5
# 28     21        Sim                   2                   4               4
# 29     22        Sim                   2                   5               5
# 30     22        Sim                   2                   3               5
# 31     20        Sim                   1                   3               5
# 32     22        Sim                   2                   1               4
# 33     25        Sim                   2                   4               5
# 34     31        Sim                   0                   1               4
# 35     20        Sim                   2                   4               5
# 36     20        Sim                   1                   2               5
# 37     23        Não                   1                   2               2
# 38     25        Sim                   2                   2               4
# 39     20        Sim                   1                   5               5
# 40     20        Sim                   1                   3               5
# 41     37        Não                   0                   1               5
# 42     19        Sim                   2                   1               5
# 43     23        Sim                   1                   2               5
# 44     28        Não                   0                   1               5
# 45     31        Não                   2                   3               3
# 46     19        Não                   0                   1               4
# 47     20        Sim                   1                   5               4
# 48     18        Não                   0                   1               1
#
#     qtd_recursos  qtd_profissionais  mercado_vagas imagem_1_1 imagem_1_2  \
# 0              4                  2              4    Direita    Direita
# 1              3                  1              2    Direita    Direita
# 2              5                  2              3    Direita    Direita
# 3              3                  2              4    Direita    Direita
# 4              4                  2              3    Direita    Direita
# 5              3                  2              2    Direita    Direita
# 6              4                  2              2    Direita    Direita
# 7              4                  3              3    Direita    Direita
# 8              3                  3              2    Direita    Direita
# 9              5                  2              1   Esquerda    Direita
# 10             3                  2              2    Direita    Direita
# 11             4                  2              3    Direita    Direita
# 12             4                  2              2    Direita    Direita
# 13             4                  3              2    Direita    Direita
# 14             3                  2              2    Direita    Direita
# 15             4                  2              3    Direita    Direita
# 16             4                  2              2    Direita    Direita
# 17             4                  2              3    Direita    Direita
# 18             4                  2              3    Direita    Direita
# 19             3                  2              3   Esquerda   Esquerda
# 20             3                  2              1    Direita    Direita
# 21             4                  1              2    Direita    Direita
# 22             3                  2              4    Direita    Direita
# 23             4                  3              2    Direita    Direita
# 24             4                  3              4    Direita    Direita
# 25             4                  2              2    Direita    Direita
# 26             4                  2              2    Direita    Direita
# 27             3                  3              2    Direita    Direita
# 28             3                  1              1    Direita    Direita
# 29             2                  1              2    Direita    Direita
# 30             4                  2              1    Direita    Direita
# 31             3                  3              2    Direita    Direita
# 32             3                  2              3    Direita   Esquerda
# 33             4                  2              2    Direita    Direita
# 34             3                  3              3   Esquerda   Esquerda
# 35             4                  2              1    Direita    Direita
# 36             4                  2              1    Direita    Direita
# 37             3                  1              4    Direita    Direita
# 38             5                  3              5    Direita    Direita
# 39             4                  2              4    Direita    Direita
# 40             5                  2              2    Direita    Direita
# 41             5                  2              3    Direita    Direita
# 42             5                  2              3    Direita    Direita
# 43             4                  2              3   Esquerda   Esquerda
# 44             5                  3              1    Direita    Direita
# 45             3                  2              3    Direita    Direita
# 46             4                  2              2    Direita    Direita
# 47             4                  2              2    Direita    Direita
# 48             1                  1              1    Direita    Direita
#
#    imagem_2_1 imagem_2_2 imagem_3_1 imagem_3_2 imagem_4_1 imagem_4_2  \
# 0     Direita    Direita   Esquerda   Esquerda    Direita    Direita
# 1     Direita    Direita    Direita    Direita    Direita    Direita
# 2     Direita    Direita    Direita    Direita    Direita    Direita
# 3     Direita    Direita    Direita    Direita   Esquerda   Esquerda
# 4     Direita    Direita    Direita    Direita    Direita   Esquerda
# 5     Direita    Direita    Direita    Direita    Direita    Direita
# 6     Direita    Direita    Direita    Direita    Direita    Direita
# 7     Direita    Direita    Direita    Direita    Direita    Direita
# 8     Direita   Esquerda    Direita    Direita    Direita    Direita
# 9    Esquerda    Direita    Direita    Direita    Direita    Direita
# 10    Direita    Direita    Direita    Direita    Direita    Direita
# 11    Direita    Direita    Direita    Direita    Direita    Direita
# 12    Direita    Direita    Direita    Direita    Direita    Direita
# 13    Direita    Direita    Direita    Direita    Direita    Direita
# 14    Direita    Direita    Direita    Direita    Direita    Direita
# 15    Direita    Direita    Direita    Direita    Direita    Direita
# 16    Direita    Direita    Direita    Direita    Direita    Direita
# 17    Direita    Direita    Direita    Direita    Direita    Direita
# 18    Direita    Direita    Direita    Direita    Direita    Direita
# 19    Direita    Direita   Esquerda   Esquerda   Esquerda   Esquerda
# 20    Direita    Direita    Direita    Direita    Direita    Direita
# 21    Direita    Direita    Direita    Direita    Direita    Direita
# 22    Direita    Direita    Direita    Direita   Esquerda    Direita
# 23    Direita    Direita    Direita    Direita    Direita    Direita
# 24    Direita    Direita    Direita    Direita   Esquerda   Esquerda
# 25    Direita    Direita    Direita    Direita    Direita    Direita
# 26   Esquerda   Esquerda    Direita    Direita   Esquerda   Esquerda
# 27   Esquerda   Esquerda    Direita    Direita    Direita    Direita
# 28    Direita    Direita    Direita    Direita    Direita    Direita
# 29    Direita    Direita    Direita    Direita    Direita    Direita
# 30    Direita    Direita    Direita    Direita    Direita    Direita
# 31    Direita    Direita    Direita    Direita    Direita    Direita
# 32    Direita    Direita    Direita    Direita   Esquerda    Direita
# 33    Direita    Direita    Direita    Direita    Direita    Direita
# 34   Esquerda   Esquerda    Direita    Direita    Direita    Direita
# 35    Direita    Direita    Direita    Direita    Direita    Direita
# 36    Direita    Direita    Direita    Direita    Direita    Direita
# 37    Direita   Esquerda    Direita    Direita    Direita    Direita
# 38    Direita    Direita    Direita    Direita    Direita    Direita
# 39    Direita    Direita    Direita    Direita    Direita    Direita
# 40    Direita    Direita    Direita    Direita   Esquerda   Esquerda
# 41   Esquerda   Esquerda    Direita    Direita    Direita    Direita
# 42    Direita    Direita    Direita    Direita    Direita    Direita
# 43    Direita    Direita    Direita    Direita    Direita    Direita
# 44   Esquerda   Esquerda   Esquerda   Esquerda    Direita    Direita
# 45    Direita    Direita    Direita    Direita    Direita    Direita
# 46   Esquerda   Esquerda    Direita    Direita    Direita    Direita
# 47    Direita    Direita    Direita    Direita    Direita    Direita
# 48    Direita    Direita    Direita    Direita    Direita    Direita
#
#    imagem_5_1 imagem_5_2
# 0     Direita    Direita
# 1     Direita    Direita
# 2    Esquerda    Direita
# 3    Esquerda   Esquerda
# 4     Direita    Direita
# 5    Esquerda    Direita
# 6    Esquerda    Direita
# 7     Direita    Direita
# 8    Esquerda    Direita
# 9     Direita    Direita
# 10    Direita    Direita
# 11    Direita    Direita
# 12    Direita    Direita
# 13    Direita    Direita
# 14    Direita    Direita
# 15    Direita    Direita
# 16   Esquerda   Esquerda
# 17    Direita    Direita
# 18    Direita    Direita
# 19    Direita    Direita
# 20    Direita    Direita
# 21   Esquerda    Direita
# 22   Esquerda    Direita
# 23    Direita    Direita
# 24   Esquerda   Esquerda
# 25    Direita    Direita
# 26   Esquerda   Esquerda
# 27    Direita    Direita
# 28   Esquerda    Direita
# 29    Direita    Direita
# 30    Direita    Direita
# 31    Direita    Direita
# 32    Direita    Direita
# 33   Esquerda    Direita
# 34   Esquerda   Esquerda
# 35    Direita    Direita
# 36    Direita    Direita
# 37   Esquerda   Esquerda
# 38    Direita    Direita
# 39   Esquerda    Direita
# 40    Direita    Direita
# 41    Direita    Direita
# 42    Direita    Direita
# 43    Direita    Direita
# 44   Esquerda   Esquerda
# 45   Esquerda    Direita
# 46    Direita    Direita
# 47   Esquerda    Direita
# 48   Esquerda    Direita

# %%
conhece_ux = data.groupby("conhece_ux")["conhece_ux"].count()
plt.title("Quantidade de conhecedores de UX", fontsize=15)
plt.ylabel("Quantidade", fontsize=12)
plt.xlabel("Resposta", fontsize=12)
plt.bar(conhece_ux.index, conhece_ux.values,color=['#a31a1a','#0029cc'], edgecolor="#a1a1a1", alpha=0.75)
plt.show()

# %%
subset = data["experiencia_design"]
subset.describe(), str("Mediana: {}".format(subset.median()))
# Out:
# (count    49.000000
#  mean      2.489796
#  std       1.371168
#  min       1.000000
#  25%       1.000000
#  50%       3.000000
#  75%       4.000000
#  max       5.000000
#  Name: experiencia_design, dtype: float64,
#  'Mediana: 3.0')

# %%
experiencia_design = data.groupby("experiencia_design")["experiencia_design"].count()
experiencia_design.index = ["Nenhuma", "Pouca", "Razoável", "Boa", "Muito alta"]
plt.title("Níveis de experiência design de interfaces", fontsize=15)
plt.xlabel("Quantidade", fontsize=12)
plt.xticks(np.arange(0, 25, step=2))
plt.ylabel("Nível de conhecimento", fontsize=12)
plt.barh(experiencia_design.index, experiencia_design.values, color=['#cc0e00',"#ccad00","#36cc00","#00becc", '#0029cc'], alpha=0.75, edgecolor="#a1a1a1")
plt.show()

# %%
subset = data["importancia_ux"]
subset.describe(), str("Mediana: {}".format(subset.median()))
# Out:
# (count    49.000000
#  mean      4.591837
#  std       0.814411
#  min       1.000000
#  25%       4.000000
#  50%       5.000000
#  75%       5.000000
#  max       5.000000
#  Name: importancia_ux, dtype: float64,
#  'Mediana: 5.0')

# %%
importancia_ux = data.groupby("importancia_ux")["importancia_ux"].count()
importancia_ux.index = ["Irrelevante", "Pouco relevante", "Razoável", "Relevante", "Indispensável"]

plt.title("Importância de pensar em UX no projeto", fontsize=15)
plt.xlabel("Frequência", fontsize=12)
plt.ylabel("Nível de importância", fontsize=12)
plt.barh(importancia_ux.index, importancia_ux.values, color=['#cc0e00',"#ccad00","#36cc00","#00becc", '#0029cc'], alpha=0.75, edgecolor="#a1a1a1")
plt.show()

# %%
subset = data["qtd_recursos"]
subset.describe(), str("Mediana: {}".format(subset.median()))
# Out:
# (count    49.000000
#  mean      3.714286
#  std       0.816497
#  min       1.000000
#  25%       3.000000
#  50%       4.000000
#  75%       4.000000
#  max       5.000000
#  Name: qtd_recursos, dtype: float64,
#  'Mediana: 4.0')

# %%
qtd_recursos = data.groupby("qtd_recursos")["qtd_recursos"].count()
qtd_recursos.index = ["Muito pouco", "Pouco", "Razoável", "Grande", "Muito grande"]
plt.title("Quantidade de recursos alocados para UX", fontsize=15)
plt.xlabel("Frequência", fontsize=12)
plt.ylabel("Quantidade de recursos", fontsize=12)
plt.barh(qtd_recursos.index, qtd_recursos.values, color=['#cc0e00',"#ccad00","#36cc00","#00becc", '#0029cc'], alpha=0.75, edgecolor="#a1a1a1")
plt.show()

# %%
subset = data["qtd_profissionais"]
subset.describe(), str("Mediana: {}".format(subset.median()))
# Out:
# (count    49.000000
#  mean      2.081633
#  std       0.571429
#  min       1.000000
#  25%       2.000000
#  50%       2.000000
#  75%       2.000000
#  max       3.000000
#  Name: qtd_profissionais, dtype: float64,
#  'Mediana: 2.0')

# %%
quantidade_profissionais = data.groupby("qtd_profissionais")["qtd_profissionais"].count()
quantidade_profissionais.index = ["Poucos", "Razoáveis", "Muitos"]

plt.title("Quantidade de profissionais qualificados", fontsize=15)
plt.ylabel("Frequência", fontsize=12)
plt.xlabel("Quantidade de profissionais", fontsize=12)
plt.bar(quantidade_profissionais.index, quantidade_profissionais.values, color=['#cc0e00',"#ccad00","#36cc00"], alpha=0.75, edgecolor="#a1a1a1")
plt.show()

# %%
subset = data["mercado_vagas"]
subset.describe(), str("Mediana: {}".format(subset.median()))
# Out:
# (count    49.000000
#  mean      2.428571
#  std       0.978945
#  min       1.000000
#  25%       2.000000
#  50%       2.000000
#  75%       3.000000
#  max       5.000000
#  Name: mercado_vagas, dtype: float64,
#  'Mediana: 2.0')

# %%
vagas = data.groupby("mercado_vagas")["mercado_vagas"].count()
vagas.index = ["Muito Vago", "Há bastante vagas", "Razoável", "Há poucas vagas", "Saturado"]

plt.title("Mercado de vagas", fontsize=15)
plt.xlabel("Frequência", fontsize=12)
plt.ylabel("Nível", fontsize=12)
plt.xticks(np.arange(0, 25, step=2))
plt.barh(vagas.index, vagas.values, color=['#cc0e00',"#ccad00","#36cc00","#00becc", '#0029cc'], alpha=0.75, edgecolor="#a1a1a1")
plt.show()

# %%
subset = data["idade"]
subset.describe(), str("Mediana: {}".format(subset.median()))
# Out:
# (count    49.000000
#  mean     22.816327
#  std       4.567428
#  min      18.000000
#  25%      20.000000
#  50%      21.000000
#  75%      23.000000
#  max      39.000000
#  Name: idade, dtype: float64,
#  'Mediana: 21.0')

# %%
idade = data.groupby("idade")["idade"].count()

plt.title("Idades", fontsize=15)
plt.xlabel("Idade", fontsize=12)
plt.ylabel("Frequência", fontsize=12)
plt.xticks(np.arange(0, 50, step=2))
plt.bar(idade.index, idade.values, color=['#c21d1d',"#ccad00","#36cc00", "#96d4cc", "#41a6c4", "#6641c4"], alpha=0.75)
plt.show()

# %%
# Out:
# 9.8

# %%
nivel_conhecimento = data.groupby("nivel_conhecimento")["nivel_conhecimento"].count()
nivel_conhecimento.index = ["Nenhum", "Estou cursando alguma graduação relacionada", "Tenho conhecimento técnico em alguma das áreas"]

plt.title("Nível de conhecimento em desenvolvimento de sistemas", fontsize=15)
plt.ylabel("Nível", fontsize=12)
plt.xlabel("Frequência", fontsize=12)
plt.xticks(np.arange(0, 50, step=2))
plt.barh(nivel_conhecimento.index, nivel_conhecimento.values, color=['#c21d1d',"#ccad00","#36cc00"], alpha=0.75)
plt.show()
